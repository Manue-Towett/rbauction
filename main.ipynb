# %%
import re

import pandas as pd

# %%
df1 = pd.read_excel("./rbauction_2023-09-16.xlsx", dtype=str).to_dict("records")

df1[0]
# Out:
# {'YEAR': '2015',
#  'MAKE': 'KOMATSU',
#  'MODEL': 'PC490LC-11',
#  'HOURS': '5239',
#  'RBAUCTION PRICE': '160000',
#  'SALE DATE': 'Sep 14, 2023',
#  'PREVIOUS OWNER': nan,
#  'Unnamed: 7': 'KOMATSU',
#  'LINK TO LISTING': 'https://www.rbauction.com/2015-komatsu-pc490lc-11-hydraulic-excavator?invId=14147473&id=ar&auction=minneapolis-mn-2023164'}

# %%
df2 = pd.read_excel("./rbauction_2023-09-16(A1(AutoRecovered).xlsx", dtype=str).to_dict("records")

df2[0]
# Out:
# {'YEAR': '2015',
#  'MAKE': 'KOMATSU',
#  'MODEL': 'PC490LC-11',
#  'HOURS': '5239',
#  'RBAUCTION PRICE': '160000',
#  'SALE DATE': 'Sep 14, 2023',
#  'PREVIOUS OWNER': nan,
#  'LINK TO LISTING': 'https://www.rbauction.com/2015-komatsu-pc490lc-11-hydraulic-excavator?invId=14147473&id=ar&auction=minneapolis-mn-2023164',
#  'Unnamed: 8': nan,
#  'Unnamed: 9': nan}

# %%
df2[12825]
# Out:
# {'YEAR': nan,
#  'MAKE': 'AMMANN',
#  'MODEL': 'CH4900',
#  'HOURS': '1451',
#  'RBAUCTION PRICE': '4250',
#  'SALE DATE': 'Jun 07, 2023',
#  'PREVIOUS OWNER': 'rammax',
#  'LINK TO LISTING': 'https://www.rbauction.com/ammann-ch4900-tandem-roller?invId=13855806&id=ar&auction=sacramento-ca-2023212',
#  'Unnamed: 8': 'https://www.rbauction.com/ammann-ch4900-tandem-roller?invId=13855806&id=ar&auction=sacramento-ca-2023212',
#  'Unnamed: 9': nan}

# %%
df1[12825]
# Out:
# {'YEAR': nan,
#  'MAKE': 'AMMANN',
#  'MODEL': 'CH4900',
#  'HOURS': '1451',
#  'RBAUCTION PRICE': '4250',
#  'SALE DATE': 'Jun 07, 2023',
#  'PREVIOUS OWNER': nan,
#  'Unnamed: 7': nan,
#  'LINK TO LISTING': 'https://www.rbauction.com/ammann-ch4900-tandem-roller?invId=13855806&id=ar&auction=sacramento-ca-2023212'}

# %%
for product, other in zip(df1[7900:15000], df2[7900:15000]):
    product["PREVIOUS OWNER"] = other["PREVIOUS OWNER"]

df1[12825]
# Out:
# {'YEAR': nan,
#  'MAKE': 'AMMANN',
#  'MODEL': 'CH4900',
#  'HOURS': '1451',
#  'RBAUCTION PRICE': '4250',
#  'SALE DATE': 'Jun 07, 2023',
#  'PREVIOUS OWNER': 'rammax',
#  'Unnamed: 7': nan,
#  'LINK TO LISTING': 'https://www.rbauction.com/ammann-ch4900-tandem-roller?invId=13855806&id=ar&auction=sacramento-ca-2023212'}

# %%
df = pd.DataFrame(df1)[['YEAR', 'MAKE', 'MODEL', 'HOURS', 'RBAUCTION PRICE', 'SALE DATE', 'PREVIOUS OWNER', 'LINK TO LISTING']]

# %%
df.head(3)
# Out:
#    YEAR        MAKE       MODEL HOURS RBAUCTION PRICE     SALE DATE  \
# 0  2015     KOMATSU  PC490LC-11  5239          160000  Sep 14, 2023
# 1  2021        SANY     SY365LC   547          160000  Sep 14, 2023
# 2  2017  JOHN DEERE      544KII  2094          117500  Sep 14, 2023
#
#   PREVIOUS OWNER                                    LINK TO LISTING
# 0            NaN  https://www.rbauction.com/2015-komatsu-pc490lc...
# 1            NaN  https://www.rbauction.com/2021-sany-sy365lc-hy...
# 2         Murphy  https://www.rbauction.com/2017-john-deere-544k...

# %%
df_na = df.loc[df["PREVIOUS OWNER"] == "na"]

df_na.head(3)
# Out:
#     YEAR    MAKE MODEL HOURS RBAUCTION PRICE     SALE DATE PREVIOUS OWNER  \
# 85  2015  BOBCAT  T590  2902           22500  Sep 14, 2023             na
# 86  2015  BOBCAT  T590  2627           22500  Sep 14, 2023             na
# 87  2018  BOBCAT  T590  3622           22500  Sep 14, 2023             na
#
#                                       LINK TO LISTING
# 85  https://www.rbauction.com/2015-bobcat-t590-com...
# 86  https://www.rbauction.com/2015-bobcat-t590-com...
# 87  https://www.rbauction.com/2018-bobcat-t590-com...

# %%
len(df_na)
# Out:
# 276

# %%
df.loc[df["PREVIOUS OWNER"] == "na", "PREVIOUS OWNER"] = ""

# %%
df.head()
# Out:
#    YEAR        MAKE       MODEL HOURS RBAUCTION PRICE     SALE DATE  \
# 0  2015     KOMATSU  PC490LC-11  5239          160000  Sep 14, 2023
# 1  2021        SANY     SY365LC   547          160000  Sep 14, 2023
# 2  2017  JOHN DEERE      544KII  2094          117500  Sep 14, 2023
# 3  2018      DOOSAN   DX350LC-5  2759          100000  Sep 14, 2023
# 4  2016         CAT        745C  8606           95000  Sep 14, 2023
#
#   PREVIOUS OWNER                                    LINK TO LISTING
# 0            NaN  https://www.rbauction.com/2015-komatsu-pc490lc...
# 1            NaN  https://www.rbauction.com/2021-sany-sy365lc-hy...
# 2         Murphy  https://www.rbauction.com/2017-john-deere-544k...
# 3            NaN  https://www.rbauction.com/2018-doosan-dx350lc-...
# 4          Foley  https://www.rbauction.com/2016-cat-745c-articu...

# %%
df["PREVIOUS OWNER"] = df["PREVIOUS OWNER"].str.upper()

df.head()
# Out:
#    YEAR        MAKE       MODEL HOURS RBAUCTION PRICE     SALE DATE  \
# 0  2015     KOMATSU  PC490LC-11  5239          160000  Sep 14, 2023
# 1  2021        SANY     SY365LC   547          160000  Sep 14, 2023
# 2  2017  JOHN DEERE      544KII  2094          117500  Sep 14, 2023
# 3  2018      DOOSAN   DX350LC-5  2759          100000  Sep 14, 2023
# 4  2016         CAT        745C  8606           95000  Sep 14, 2023
#
#   PREVIOUS OWNER                                    LINK TO LISTING
# 0            NaN  https://www.rbauction.com/2015-komatsu-pc490lc...
# 1            NaN  https://www.rbauction.com/2021-sany-sy365lc-hy...
# 2         MURPHY  https://www.rbauction.com/2017-john-deere-544k...
# 3            NaN  https://www.rbauction.com/2018-doosan-dx350lc-...
# 4          FOLEY  https://www.rbauction.com/2016-cat-745c-articu...

# %%
df.loc[df["PREVIOUS OWNER"] == "LOUS", "PREVIOUS OWNER"] = "LOUISIANA"

# %%
df.iloc[3910:3920]
# Out:
#       YEAR       MAKE                                              MODEL  \
# 3910  2023     AGROTK                                                R35
# 3911   NaN     BALDOR                                         IGLC210-2N
# 3912   NaN        CAT                                               3412
# 3913  2016  MULTIQUIP                                       DCA-70SSIU4F
# 3914  2017       CASE                                               DV26
# 3915  2010    GRADALL                                             XL3100
# 3916  2016     WACKER                                              RD12A
# 3917   NaN        NaN  140 kW Skid-Mounted Gen Set (250-749 Kw/310-95...
# 3918  2014        CAT                                             300.9D
# 3919  2013    LAY-MOR                                              SM300
#
#       HOURS RBAUCTION PRICE     SALE DATE    PREVIOUS OWNER  \
# 3910      1            9250  Aug 24, 2023               NaN
# ...

# %%
df.loc[df["PREVIOUS OWNER"] == "LOUSIANA"]
# Out:
# Empty DataFrame
# Columns: [YEAR, MAKE, MODEL, HOURS, RBAUCTION PRICE, SALE DATE, PREVIOUS OWNER, LINK TO LISTING]
# Index: []

# %%
df.loc[df["PREVIOUS OWNER"] == "HERC RENTALS", "PREVIOUS OWNER"] = "HERCRENTALS"

# %%
df.loc[df["PREVIOUS OWNER"] == "DOGGET", "PREVIOUS OWNER"] = "DOGGETT"

# %%
df.loc[df["PREVIOUS OWNER"] == "WHEELER", "PREVIOUS OWNER"] = "WHEELEN"

# %%
df.loc[df["PREVIOUS OWNER"] == "WHEELER"]
# Out:
# Empty DataFrame
# Columns: [YEAR, MAKE, MODEL, HOURS, RBAUCTION PRICE, SALE DATE, PREVIOUS OWNER, LINK TO LISTING]
# Index: []

# %%
df.loc[df["PREVIOUS OWNER"] == "AXIS"]
# Out:
#      YEAR    MAKE                                              MODEL HOURS  \
# 3965  NaN  SHAMBO  SHAMBO Hydraulic (Inoperable) Miscellaneous In...  2735
#
#      RBAUCTION PRICE     SALE DATE PREVIOUS OWNER  \
# 3965            5000  Aug 24, 2023           AXIS
#
#                                         LINK TO LISTING
# 3965  https://www.rbauction.com/shambo-hydraulic-ino...

# %%
df.loc[df["PREVIOUS OWNER"] == "AXIS", "PREVIOUS OWNER"] = "AXIS OILFIELD RENTALS"

# %%
df.loc[df["PREVIOUS OWNER"] == "WESTCON"]
# Out:
#      YEAR MAKE                                              MODEL HOURS  \
# 3978  NaN  NaN  Quantity of (3) Electrical Panels Electrical S...     0
# 4344  NaN  NaN   Quantity of (2) Miscellaneous Industrial - Other     0
# 4356  NaN  NaN           Quantity of (3) 240V Electrical Supplies     0
# 4379  NaN  NaN           Quantity of (2) 480V Electrical Supplies     0
#
#      RBAUCTION PRICE     SALE DATE PREVIOUS OWNER  \
# 3978            4250  Aug 24, 2023        WESTCON
# 4344             600  Aug 24, 2023        WESTCON
# 4356             550  Aug 22, 2023        WESTCON
# 4379             475  Aug 24, 2023        WESTCON
#
#                                         LINK TO LISTING
# 3978  https://www.rbauction.com/quantity-of-3-electr...
# 4344  https://www.rbauction.com/quantity-of-2-miscel...
# 4356  https://www.rbauction.com/quantity-of-3-240v-e...
# 4379  https://www.rbauction.com/quantity-of-2-480v-e...

# %%
df.loc[df["PREVIOUS OWNER"] == "WESTCON", "PREVIOUS OWNER"] = "BILFINGER WESTCON"

# %%
df.loc[df["PREVIOUS OWNER"] == "IP"]
# Out:
#       YEAR        MAKE       MODEL  HOURS RBAUCTION PRICE     SALE DATE  \
# 7159  2019     KOMATSU  PC210LC-11   8048           67500  Jul 18, 2023
# 7160  2018     KOMATSU  PC360LC-11   7865           67500  Jul 18, 2023
# 7170  2018     KOMATSU  PC360LC 11   7468           65000  Jul 18, 2023
# 7182  2018     KOMATSU  PC360LC 11   7792           60000  Jul 18, 2023
# 7183  2018     KOMATSU  PC360LC-11   7624           60000  Jul 18, 2023
# 7235  2015     KOMATSU    D65PX-18   9431           45000  Jul 18, 2023
# 7289  2012  JOHN DEERE        310K   7243           34000  Jul 18, 2023
# 7370  2014     KOMATSU  PC290LC-10  10978           23000  Jul 18, 2023
#
#      PREVIOUS OWNER                                    LINK TO LISTING
# 7159             IP  https://www.rbauction.com/2019-komatsu-pc210lc...
# 7160             IP  https://www.rbauction.com/2018-komatsu-pc360lc...
# 7170             IP  https://www.rbauction.com/2018-komatsu-pc360lc...
# ...

# %%
df.loc[df["PREVIOUS OWNER"] == "IP", "PREVIOUS OWNER"] = "WAUKESHA-PEARCE"

# %%
df.loc[df["PREVIOUS OWNER"] == "HOME DEPOT", "PREVIOUS OWNER"] = "HOME DEPOT RENTAL"

# %%
from datetime import date

writer = pd.ExcelWriter("cleaned_data_{}.xlsx".format(date.today()),
                        engine="xlsxwriter",
                        engine_kwargs={'options': {'strings_to_urls': False}})

df.to_excel(writer, index=False)

writer.close()
